# %% [markdown]
# <a href="https://colab.research.google.com/github/jaaaamj0711/-Coding-practice/blob/main/Tip/add_row_%26_column.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
result.reset_index(drop=True)
# Out:
#                                    제목                날짜
# 0    인텔 의존에서 벗어난 애플, 올해 중반 신형 맥북프로 출시  2021.01.15 17:04
# 1    '노트북 성수기" 신학기 공략…삼성·LG 이어 애플도 할인  2021.01.10 17:59
# 2            "디스플레이 OLED로 대전환"…장비株 들썩  2021.01.05 17:57
# 3                깜짝실적·현금부자…'알짜株' 담아볼까  2021.01.05 17:26
# 4            PC에서 스마트폰 문자·전화·앱 그대로 쓴다  2020.12.27 17:49
# ..                                ...               ...
# 95                      경험이 우리에게 주는 것  2017.05.08 00:47
# 96        한국GM, 현금 할인·할부 프로그램 등 구매 혜택  2017.04.02 11:39
# 97  한국GM, 현금 할인 등 구매 혜택…쉐보레 도입 6주년 기념  2017.03.02 08:32
# 98    11번가, 애플 전문관 오픈…"맥북·아이워치 할인 받자"  2017.02.13 08:35
# 99         SK하이닉스, 도시바에 3조 베팅한 결정적 이유  2017.02.07 18:07
#
# [100 rows x 2 columns]

# %% [markdown]
# # 행과 열의 출력수를 늘려주는 옵션

# %%
import pandas as pd
print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

# %%
result.reset_index(drop=True)
# Out:
#                                                    제목                날짜
# 0                    인텔 의존에서 벗어난 애플, 올해 중반 신형 맥북프로 출시  2021.01.15 17:04
# 1                    '노트북 성수기" 신학기 공략…삼성·LG 이어 애플도 할인  2021.01.10 17:59
# 2                            "디스플레이 OLED로 대전환"…장비株 들썩  2021.01.05 17:57
# 3                                깜짝실적·현금부자…'알짜株' 담아볼까  2021.01.05 17:26
# 4                            PC에서 스마트폰 문자·전화·앱 그대로 쓴다  2020.12.27 17:49
# 5                     "구형 PC를 크롬북으로 바꿔준다"…구글, 네버웨어 인수  2020.12.17 14:21
# 6          "애플, 17억대 활성기기 바탕으로 스트리밍 등 플랫폼 서비스 업체로 변모"  2020.12.11 14:52
# 7                      폰 이어 자율주행차까지…깊어지는 애플-TSMC '밀월'  2020.12.11 10:28
# 8                   "애플도 인텔 칩 버린다"…'CPU 왕국' intel의 위기  2020.12.08 17:27
# 9       골드만 "증시 쉬어갈 때" vs BofA "계속 상승" [김현석의 월스트리트나우]  2020.12.08 08:06
# 10                                   애플 맥시리즈 이달 한국 출시  2020.12.07 15:22
# 11                  애플, 1년 만에 터치 결함 인정…이번엔 아이폰11 [종합]  2020.12.07 11:45
# ...
