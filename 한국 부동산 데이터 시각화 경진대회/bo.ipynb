# %% [markdown]
# <a href="https://colab.research.google.com/github/jaaaamj0711/-Coding-practice/blob/main/%ED%95%9C%EA%B5%AD%20%EB%B6%80%EB%8F%99%EC%82%B0%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%8B%9C%EA%B0%81%ED%99%94%20%EA%B2%BD%EC%A7%84%EB%8C%80%ED%9A%8C/bo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use(['classic'])

# %%
a = pd.read_csv("/content/drive/MyDrive/open (2)/지역별_지가변동률.csv", index_col=0)
a.head()
# Out:
#             전국[%]  서울[%]  부산[%]  대구[%]  ...  전남[%]  경북[%]  경남[%]  제주[%]
# 2005-01-01  0.226  0.192  0.083  0.212  ...  0.099  0.163  0.140  0.150
# 2005-02-01  0.184  0.140  0.065  0.208  ...  0.071  0.135  0.160  0.111
# 2005-03-01  0.348  0.403  0.119  0.278  ...  0.139  0.161  0.225  0.102
# 2005-04-01  0.525  0.725  0.151  0.258  ...  0.127  0.209  0.291  0.181
# 2005-05-01  0.562  0.590  0.185  0.254  ...  0.152  0.224  0.310  0.247
#
# [5 rows x 18 columns]

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

plt.style.use(['ggplot'])

# %%
# 한글 폰트 사용을 위한 설정
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
import matplotlib.font_manager as fm
fm._rebuild()
plt.rc('font', family='NanumGothic')

# %%
for fontInfo in fm.fontManager.ttflist:
    if 'Nanum' in fontInfo.name:
        print(fontInfo.name+" = "+fontInfo.fname)

# %%
a.index = pd.to_datetime(a.index)

# %%
drange
print(df.iloc[:,:3])

# %%
drange.iloc[:,9:]
# Out:
#             경기[%]  강원[%]  충북[%]  충남[%]  전북[%]  전남[%]  경북[%]  경남[%]  제주[%]
# 2019-01-01  0.323  0.254  0.208  0.134  0.223  0.361  0.206  0.080  0.221
# 2019-02-01  0.313  0.215  0.214  0.124  0.224  0.311  0.174  0.072  0.121
# 2019-03-01  0.350  0.238  0.252  0.154  0.290  0.359  0.229  0.082  0.093
# 2019-04-01  0.351  0.257  0.233  0.154  0.262  0.352  0.226  0.092  0.103
# 2019-05-01  0.351  0.249  0.209  0.142  0.255  0.326  0.213  0.066 -0.133
# 2019-06-01  0.350  0.227  0.162  0.144  0.224  0.324  0.198  0.046 -0.112
# 2019-07-01  0.356  0.240  0.144  0.121  0.233  0.321  0.196  0.049 -0.131
# 2019-08-01  0.361  0.213  0.134  0.108  0.215  0.302  0.176  0.008 -0.191
# 2019-09-01  0.351  0.188  0.129  0.101  0.175  0.284  0.173 -0.003 -0.408
# 2019-10-01  0.384  0.174  0.168  0.123  0.172  0.308  0.187  0.019 -0.417
# 2019-11-01  0.360  0.185  0.171  0.136  0.153  0.295  0.184  0.014 -0.522
# 2019-12-01  0.358  0.182  0.175  0.178  0.140  0.284  0.192  0.031 -0.402
# ...

# %%
drange[0:9].columns.values
# Out:
# array(['전국[%]', '서울[%]', '부산[%]', '대구[%]', '인천[%]', '광주[%]', '대전[%]',
#        '울산[%]', '세종[%]', '경기[%]', '강원[%]', '충북[%]', '충남[%]', '전북[%]',
#        '전남[%]', '경북[%]', '경남[%]', '제주[%]'], dtype=object)

# %%
warnings.filterwarnings('ignore')
plt.subplots(figsize = (20,6))
plt.plot(drange.iloc[:,:9].index, drange.iloc[:,:9].values)
plt.legend(drange.iloc[:,:9].columns.values, bbox_to_anchor=(1.1, 1))
plt.axvline(x = pd.to_datetime("2020-02-02"), color='gray', linestyle=':', linewidth=10)

# %%
warnings.filterwarnings('ignore')
plt.subplots(figsize = (20,6))
plt.plot(drange.iloc[:,9:].index, drange.iloc[:,9:].values)
plt.legend(drange.iloc[:,9:].columns.values, bbox_to_anchor=(1.1, 1))
plt.axvline(x = pd.to_datetime("2020-02-02"), color='gray', linestyle=':', linewidth=10)

# %%
b = pd.read_csv("/content/drive/MyDrive/open (2)/아파트 실거래가격지수.csv", index_col=0)

# %%
b.head()
# Out:
#             도심권[2017.11=100]  ...  지방[2017.11=100]
# 2006-01-01              59.3  ...             59.1
# 2006-02-01              58.1  ...             59.2
# 2006-03-01              59.5  ...             59.2
# 2006-04-01              59.5  ...             59.2
# 2006-05-01              61.4  ...             59.1
#
# [5 rows x 28 columns]

# %%
warnings.filterwarnings('ignore')
plt.subplots(figsize = (20,6))
plt.plot(brange.iloc[:,9:].index, brange.iloc[:,9:].values)
plt.legend(brange.iloc[:,9:].columns.values, bbox_to_anchor=(1.3, 1))
plt.axvline(x = pd.to_datetime("2020-02-02"), color='gray', linestyle=':', linewidth=10)

# %%
b.index = pd.to_datetime(b.index)

# %%
brange = b.loc["2019-01-01": "2021-01-01"]

# %%
c = pd.read_csv("/content/drive/MyDrive/open (2)/유형별_주택월세통합가격지수.csv", index_col=0)
c.head()
# Out:
#             종합-전국[2017.11=100]  ...  단독주택-9개도[2017.11=100]
# 2015-06-01               100.2  ...                  100.1
# 2015-07-01               100.2  ...                  100.2
# 2015-08-01               100.3  ...                  100.2
# 2015-09-01               100.3  ...                  100.2
# 2015-10-01               100.4  ...                  100.2
#
# [5 rows x 96 columns]

# %%
crange = c.loc["2019-01-01": "2021-01-01"]

# %%
warnings.filterwarnings('ignore')
plt.subplots(figsize = (20,6))
plt.plot(crange.iloc[:,24:48].index, crange.iloc[:,24:48].values)
plt.legend(crange.iloc[:,24:48].columns.values, bbox_to_anchor=(1.3, 1))
plt.axvline(x = pd.to_datetime("2020-02-02"), color='gray', linestyle=':', linewidth=10)

# %%
warnings.filterwarnings('ignore')
plt.subplots(figsize = (20,6))
plt.plot(crange.iloc[:,48:72].index, crange.iloc[:,48:72].values)
plt.legend(crange.iloc[:,48:72].columns.values, bbox_to_anchor=(1.3, 1))
plt.axvline(x = pd.to_datetime("2020-02-02"), color='gray', linestyle=':', linewidth=10)

# %%
warnings.filterwarnings('ignore')
plt.subplots(figsize = (20,6))
plt.plot(crange.iloc[:,72:96].index, crange.iloc[:,72:96].values)
plt.legend(crange.iloc[:,72:96].columns.values, bbox_to_anchor=(1.3, 1))
plt.axvline(x = pd.to_datetime("2020-02-02"), color='gray', linestyle=':', linewidth=10)

# %%
c.index = pd.to_datetime(c.index)
